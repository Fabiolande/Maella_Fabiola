# %% [markdown]
# <a href="https://colab.research.google.com/github/Fabiolande/Maella_Fabiola/blob/main/TPdataIA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 30.4 MB/s eta 0:00:00
# ...

# %%
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.3.229 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 38.7/112.6 GB disk)

# %%
from ultralytics import YOLO

# %%
model = YOLO('yolov8n.pt')

# %%
# !unzip -q "/NEU-DET.v1-ipor_final.yolov8.zip" -d dataset2

# %%
results = model.train(data='dataset/data.yaml', epochs=25, imgsz=640)
# Out:
# Ultralytics 8.3.229 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
model_trained = YOLO('runs/detect/train3/weights/best.pt')

# %%
model_trained.predict('/content/dataset2/train/images/crazing_100_jpg.rf.fa24606525ba9c6e986d813757651ea4.jpg', save=True)
# Out:
# image 1/1 /content/dataset2/train/images/crazing_100_jpg.rf.fa24606525ba9c6e986d813757651ea4.jpg: 640x640 1 crazing, 9.9ms
# Speed: 4.2ms preprocess, 9.9ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to /content/runs/detect/predict
# [ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'crazing', 1: 'inclusion', 2: 'patches', 3: 'pitted_surface', 4: 'rolled-in_scale', 5: 'scratches'}
#  obb: None
#  orig_img: array([[[125, 125, 125],
#          [129, 129, 129],
#          [117, 117, 117],
#          ...,
#          [109, 109, 109],
#          [115, 115, 115],
#          [121, 121, 121]],
#
#         [[118, 118, 118],
#          [118, 118, 118],
#          [108, 108, 108],
#          ...,
#          [109, 109, 109],
#          [112, 112, 112],
#          [117, 117, 117]],
#
#         [[117, 117, 117],
#          [146, 146, 146],
# ...

# %%
model_trained.predict('/content/dataset2/train/images/crazing_102_jpg.rf.98f4074d8fbe18d7c7d288ec336cd7d7.jpg', save=True)
# Out:
# image 1/1 /content/dataset2/train/images/crazing_102_jpg.rf.98f4074d8fbe18d7c7d288ec336cd7d7.jpg: 640x640 2 crazings, 10.2ms
# Speed: 4.0ms preprocess, 10.2ms inference, 2.6ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to /content/runs/detect/predict
# [ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'crazing', 1: 'inclusion', 2: 'patches', 3: 'pitted_surface', 4: 'rolled-in_scale', 5: 'scratches'}
#  obb: None
#  orig_img: array([[[162, 162, 162],
#          [172, 172, 172],
#          [184, 184, 184],
#          ...,
#          [ 57,  57,  57],
#          [ 67,  67,  67],
#          [  0,   0,   0]],
#
#         [[159, 159, 159],
#          [158, 158, 158],
#          [  0,   0,   0],
#          ...,
#          [ 72,  72,  72],
#          [ 86,  86,  86],
#          [ 65,  65,  65]],
#
#         [[179, 179, 179],
#          [169, 169, 169],
# ...
